# %%
import pandas as pd
import streamlit as st

# %%
df = pd.read_parquet("cleaned.parquet")
df
# Out:
#     trade_date ticker  open_price  close_price    volume  \
# 0   2025-09-01   AAPL      192.47       191.90  21646536
# 1   2025-09-01   MSFT      456.51       459.76      <NA>
# 2   2025-09-01   None      151.27       150.45  20405836
# 3   2025-09-01   None      139.61       141.17  12795579
# 4   2025-09-01   None     1190.21      1198.56  16389274
# ..         ...    ...         ...          ...       ...
# 195 2025-10-03  GOOGL         NaN       142.58  13081100
# 196 2025-10-03   NVDA         NaN      1189.83  16429220
# 197 2025-10-03   None         NaN       247.66      <NA>
# 198 2025-10-03   META      499.14       500.78      <NA>
# 199 2025-10-03   NFLX      608.54       606.87      <NA>
#
#                      sector validated currency exchange         notes
# 0                Technology      None     None   NASDAQ        gap up
# 1                Technology      None     None     None          None
# 2    Consumer Discretionary      None      USD   NASDAQ          None
# 3                      None      True     None     NYSE      gap down
# 4            Semiconductors      None      USD     NYSE          None
# ..                      ...       ...      ...      ...           ...
# 195  Communication Services     False      USD   NASDAQ      gap down
# 196          Semiconductors      None     None     None          None
# 197              Automotive      None     None     NYSE  pre-earnings
# 198  Communication Services     False     None   NASDAQ          None
# 199                    None      True     None     None        gap up
#
# [200 rows x 10 columns]

# %%
csv = pd.read_csv("cleaned_step1.csv")
csv
# Out:
#      trade_date ticker  open_price  close_price      volume  \
# 0    2025-09-01   AAPL      192.47       191.90  21646536.0
# 1    2025-09-01   MSFT      456.51       459.76         NaN
# 2    2025-09-01    NaN      151.27       150.45  20405836.0
# 3    2025-09-01    NaN      139.61       141.17  12795579.0
# 4    2025-09-01    NaN     1190.21      1198.56  16389274.0
# ..          ...    ...         ...          ...         ...
# 195  2025-10-03  GOOGL         NaN       142.58  13081100.0
# 196  2025-10-03   NVDA         NaN      1189.83  16429220.0
# 197  2025-10-03    NaN         NaN       247.66         NaN
# 198  2025-10-03   META      499.14       500.78         NaN
# 199  2025-10-03   NFLX      608.54       606.87         NaN
#
#                      sector validated currency exchange         notes
# 0                Technology       NaN      NaN   NASDAQ        gap up
# 1                Technology       NaN      NaN      NaN           NaN
# 2    Consumer Discretionary       NaN      USD   NASDAQ           NaN
# 3                       NaN       YES      NaN     NYSE      gap down
# 4            Semiconductors       NaN      USD     NYSE           NaN
# ..                      ...       ...      ...      ...           ...
# 195  Communication Services        NO      USD   NASDAQ      gap down
# 196          Semiconductors       NaN      NaN      NaN           NaN
# 197              Automotive       NaN      NaN     NYSE  pre-earnings
# 198  Communication Services        NO      NaN   NASDAQ           NaN
# 199                     NaN       YES      NaN      NaN        gap up
#
# [200 rows x 10 columns]

# %%
ag1 = pd.read_parquet("agg1.parquet")
ag1
# Out:
#                    sector  avg_close_price
# 0              Automotive           246.65
# 1  Communication Services           412.44
# 2  Consumer Discretionary           152.10
# 3          Semiconductors          1176.62
# 4              Technology           316.55

# %%
ag2 = pd.read_parquet("agg2.parquet")
ag2
# Out:
#    trade_date  daily_avg_close
# 0  2025-09-01           434.63
# 1  2025-09-02           473.68
# 2  2025-09-03           411.69
# 3  2025-09-04           509.46
# 4  2025-09-05           539.41
# 5  2025-09-08           459.94
# 6  2025-09-09           420.90
# 7  2025-09-10           431.78
# 8  2025-09-11           419.54
# 9  2025-09-12           478.20
# 10 2025-09-15           325.34
# 11 2025-09-16           516.82
# 12 2025-09-17           523.02
# 13 2025-09-18           578.13
# 14 2025-09-19           299.35
# 15 2025-09-22           432.02
# 16 2025-09-23           509.41
# 17 2025-09-24           325.74
# 18 2025-09-25           297.98
# 19 2025-09-26           514.30
# 20 2025-09-29           429.44
# 21 2025-09-30           444.58
# 22 2025-10-01           400.91
# 23 2025-10-02           466.29
# 24 2025-10-03           435.48

# %%
ag3 = pd.read_parquet("agg3.parquet")
ag3
# Out:
#                    sector  avg_volume
# 0              Automotive  17404401.0
# 1  Communication Services  16238718.0
# 2  Consumer Discretionary  16256342.0
# 3          Semiconductors  16910619.0
# 4              Technology  15597119.0

# %%
# Load data
@st.cache_data
def load_data():
    agg1 = pd.read_parquet("agg1.parquet")  # avg close price per sector
    agg2 = pd.read_parquet("agg2.parquet")  # daily avg close price across all tickers
    agg3 = pd.read_parquet("agg3.parquet")  # avg volume by sector
    return agg1, agg2, agg3

agg1, agg2, agg3 = load_data()


# Sidebar Filters

st.sidebar.header("Filters")

# Date range filter (for agg2)
if "trade_date" in agg2.columns:
    min_date = pd.to_datetime(agg2["trade_date"].min())
    max_date = pd.to_datetime(agg2["trade_date"].max())
    start_date, end_date = st.sidebar.date_input(
        "Select Date Range", [min_date, max_date], min_value=min_date, max_value=max_date
    )
else:
    start_date, end_date = None, None

# Sector filter (for agg1 and agg3)
sectors = agg1["sector"].dropna().unique().tolist()
selected_sectors = st.sidebar.multiselect("Select Sector(s)", sectors, default=sectors)

# Filter Data

agg1_filtered = agg1[agg1["sector"].isin(selected_sectors)]
agg3_filtered = agg3[agg3["sector"].isin(selected_sectors)]

agg2_filtered = agg2.copy()
if start_date and end_date:
    agg2_filtered["trade_date"] = pd.to_datetime(agg2_filtered["trade_date"])
    agg2_filtered = agg2_filtered[
        (agg2_filtered["trade_date"] >= pd.to_datetime(start_date)) &
        (agg2_filtered["trade_date"] <= pd.to_datetime(end_date))
    ]


# Main Dashboard
st.title("Stock Market Aggregates Dashboard 📊")
# Out:
# 2025-11-14 15:10:39.545 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-14 15:10:39.547 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.610
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/attanasia/venv/lib/python3.8/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-11-14 15:10:39.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.612 No runtime found, using MemoryCacheStorageManager
# 2025-11-14 15:10:39.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.header("Average Closing Price per Sector")
st.dataframe(agg1_filtered)
st.bar_chart(data=agg1_filtered.set_index("sector")["avg_close_price"])
# Out:
# 2025-11-14 15:10:39.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.header("Daily Average Close Price Across All Tickers")
st.line_chart(agg2_filtered.set_index("trade_date")["daily_avg_close"])
# Out:
# 2025-11-14 15:10:39.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.header("Average Volume per Sector")
st.dataframe(agg3_filtered)
st.bar_chart(data=agg3_filtered.set_index("sector")["avg_volume"])
# Out:
# 2025-11-14 15:10:39.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 15:10:39.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
